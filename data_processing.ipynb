# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('../dataset/train.csv')

# %%
train
# Out:
#       Component1_fraction  Component2_fraction  Component3_fraction  \
# 0                    0.21                 0.00                 0.42
# 1                    0.02                 0.33                 0.19
# 2                    0.08                 0.08                 0.18
# 3                    0.25                 0.42                 0.00
# 4                    0.26                 0.16                 0.08
# ...                   ...                  ...                  ...
# 1995                 0.50                 0.12                 0.00
# 1996                 0.19                 0.31                 0.00
# 1997                 0.38                 0.06                 0.14
# 1998                 0.50                 0.16                 0.00
# 1999                 0.00                 0.34                 0.21
#
#       Component4_fraction  Component5_fraction  Component1_Property1  \
# 0                    0.25                 0.12             -0.021782
# ...

# %%
train.columns
# Out:
# Index(['Component1_fraction', 'Component2_fraction', 'Component3_fraction',
#        'Component4_fraction', 'Component5_fraction', 'Component1_Property1',
#        'Component2_Property1', 'Component3_Property1', 'Component4_Property1',
#        'Component5_Property1', 'Component1_Property2', 'Component2_Property2',
#        'Component3_Property2', 'Component4_Property2', 'Component5_Property2',
#        'Component1_Property3', 'Component2_Property3', 'Component3_Property3',
#        'Component4_Property3', 'Component5_Property3', 'Component1_Property4',
#        'Component2_Property4', 'Component3_Property4', 'Component4_Property4',
#        'Component5_Property4', 'Component1_Property5', 'Component2_Property5',
#        'Component3_Property5', 'Component4_Property5', 'Component5_Property5',
#        'Component1_Property6', 'Component2_Property6', 'Component3_Property6',
#        'Component4_Property6', 'Component5_Property6', 'Component1_Property7',
# ...

# %%
test=pd.read_csv('../dataset/test.csv')

# %%
test
# Out:
#       ID  Component1_fraction  Component2_fraction  Component3_fraction  \
# 0      1                 0.18                 0.05                 0.32
# 1      2                 0.00                 0.50                 0.00
# 2      3                 0.16                 0.00                 0.17
# 3      4                 0.50                 0.00                 0.17
# 4      5                 0.00                 0.00                 0.50
# ..   ...                  ...                  ...                  ...
# 495  496                 0.44                 0.01                 0.08
# 496  497                 0.19                 0.47                 0.03
# 497  498                 0.43                 0.01                 0.12
# 498  499                 0.03                 0.04                 0.42
# 499  500                 0.00                 0.50                 0.00
#
#      Component4_fraction  Component5_fraction  Component1_Property1  \
# ...

# %%
test.columns
# Out:
# Index(['ID', 'Component1_fraction', 'Component2_fraction',
#        'Component3_fraction', 'Component4_fraction', 'Component5_fraction',
#        'Component1_Property1', 'Component2_Property1', 'Component3_Property1',
#        'Component4_Property1', 'Component5_Property1', 'Component1_Property2',
#        'Component2_Property2', 'Component3_Property2', 'Component4_Property2',
#        'Component5_Property2', 'Component1_Property3', 'Component2_Property3',
#        'Component3_Property3', 'Component4_Property3', 'Component5_Property3',
#        'Component1_Property4', 'Component2_Property4', 'Component3_Property4',
#        'Component4_Property4', 'Component5_Property4', 'Component1_Property5',
#        'Component2_Property5', 'Component3_Property5', 'Component4_Property5',
#        'Component5_Property5', 'Component1_Property6', 'Component2_Property6',
#        'Component3_Property6', 'Component4_Property6', 'Component5_Property6',
# ...

# %%
train.isna().sum().sum()
# Out:
# 0

# %%
train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### No duplicates no Nulls

# %%
train['Component5_fraction'].describe()
# Out:
# count    2000.000000
# mean        0.114490
# std         0.080219
# min         0.000000
# 25%         0.050000
# 50%         0.120000
# 75%         0.180000
# max         0.290000
# Name: Component5_fraction, dtype: float64

# %%
train['Component1_fraction'].describe()
# Out:
# count    2000.00000
# mean        0.18069
# std         0.16320
# min         0.00000
# 25%         0.03000
# 50%         0.14000
# 75%         0.29000
# max         0.50000
# Name: Component1_fraction, dtype: float64

# %%
train['Component2_fraction'].describe()
# Out:
# count    2000.000000
# mean        0.182910
# std         0.163704
# min         0.000000
# 25%         0.040000
# 50%         0.150000
# 75%         0.300000
# max         0.500000
# Name: Component2_fraction, dtype: float64

# %%
train['Component3_fraction'].describe()
# Out:
# count    2000.000000
# mean        0.179820
# std         0.166283
# min         0.000000
# 25%         0.020000
# 50%         0.140000
# 75%         0.290000
# max         0.500000
# Name: Component3_fraction, dtype: float64

# %%
train['Component4_fraction'].describe()
# Out:
# count    2000.000000
# mean        0.342090
# std         0.141119
# min         0.010000
# 25%         0.220000
# 50%         0.350000
# 75%         0.500000
# max         0.500000
# Name: Component4_fraction, dtype: float64
